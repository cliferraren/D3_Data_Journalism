# %%
#Import Dependecies
import pandas as pd

# %%
povertyDF = pd.read_csv('data/poverty_status/ACS_14_1YR_S1701_with_ann.csv')
povertyDF[:5]
# Out:
#         GEO.id GEO.id2 GEO.display-label  \
# 0           Id     Id2         Geography
# 1  0400000US01       1           Alabama
# 2  0400000US02       2            Alaska
# 3  0400000US04       4           Arizona
# 4  0400000US05       5          Arkansas
#
#                                        HC01_EST_VC01  \
# 0  Total; Estimate; Population for whom poverty s...
# 1                                            4727549
# 2                                             717723
# 3                                            6573369
# 4                                            2882856
#
#                                        HC01_MOE_VC01  \
# 0  Total; Margin of Error; Population for whom po...
# 1                                               2783
# 2                                                893
# 3                                               3679
# 4                                               1835
#
#                                        HC02_EST_VC01  \
# ...

# %%
povertyDF = povertyDF.iloc[:,[0,2,7]]

# %%
povertyDF.head()
# Out:
#         GEO.id GEO.display-label  \
# 0           Id         Geography
# 1  0400000US01           Alabama
# 2  0400000US02            Alaska
# 3  0400000US04           Arizona
# 4  0400000US05          Arkansas
#
#                                        HC03_EST_VC01
# 0  Percent below poverty level; Estimate; Populat...
# 1                                               19.3
# 2                                               11.2
# 3                                               18.2
# 4                                               18.9

# %%
povertyDF = povertyDF.drop([0])
povertyDF = povertyDF.rename(columns={'GEO.id': 'id', 'GEO.display-label': 'state','HC03_EST_VC01':"Poverty Percentage"})

# %%
povertyDF[:5]
# Out:
#             id       state Poverty Percentage
# 1  0400000US01     Alabama               19.3
# 2  0400000US02      Alaska               11.2
# 3  0400000US04     Arizona               18.2
# 4  0400000US05    Arkansas               18.9
# 5  0400000US06  California               16.4
